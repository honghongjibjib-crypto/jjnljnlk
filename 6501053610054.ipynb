# %%
x=10
x
# Out:
# 10

# %%
y=3.5
y
# Out:
# 3.5

# %%
name= "balloon"
name
# Out:
# 'balloon'

# %%
flag = True
flag
# Out:
# True

# %%
scores =[70,80,90]
scores
# Out:
# [70, 80, 90]

# %%
scores[0]
# Out:
# 70

# %%
scores[0:2]
# Out:
# [70, 80]

# %%
scores.append(100)
scores
# Out:
# [70, 80, 90, 100]

# %%
student ={"name":["ann","balloon"],"age":20,"major":"Logistics"}
print(student["name"])
# Out:
# ['ann', 'balloon']

# %%
score = 90
if score >= 80:
    grade = "A"
elif score >= 70:
    grade = "B"
else:
    grade = "C"  
    
    
grade
# Out:
# 'A'

# %%
scores = [1,2,3]
for s in scores:
    print (s)
# Out:
# 1
# 2
# 3

# %%
def bmi(weight,height):
    return weight/(height**2)
print(bmi(60,1.65))
# Out:
# 22.03856749311295

# %%
import pandas as pd

# %%
df = pd.read_csv("salaries.csv")
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]
