# %%
import pandas as pd

# %%
import statsmodels.api as sm

# %%
df = pd.read_csv('advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.shape
# Out:
# (200, 4)

# %%
df.describe ()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["TV"],df["Sales"])
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
df_simple=df[["TV","Sales"]]

# %%
x= df_simple["TV"]
y= df_simple["Sales"]

# %%
x=sm.add_constant(x)

# %%
model=sm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     856.2
# Date:                Thu, 08 Jan 2026   Prob (F-statistic):           7.93e-74
# Time:                        09:44:44   Log-Likelihood:                -448.99
# No. Observations:                 200   AIC:                             902.0
# Df Residuals:                     198   BIC:                             908.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9748      0.323     21.624      0.000       6.339       7.611
# TV             0.0555      0.002     29.260      0.000       0.052       0.059
# ==============================================================================
# Omnibus:                        0.013   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.993   Jarque-Bera (JB):                0.043
# Skew:                          -0.018   Prob(JB):                        0.979
# Kurtosis:                       2.938   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_simple['y_perd']=model.predict(x)
# Out:
# <ipython-input-36-5401466ef62a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_simple['y_pd']=model.predict(x)

# %%
df_simple['res']=df_simple['Sales']-df_simple['y_pred']
# Out:
# <ipython-input-37-abff87c35237>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_simple['res']=df_simple['Sales']-df_simple['y_pred']

# %%
residuals=df_simple['res']
x=df_simple['TV']
plt.scatter(x,residuals)
plt.axhline(0,color='red')
plt.xlabel("X")
plt.ylabel("Residuals")
plt.show()

# %%
import pandas as pd

# %%
import statsmodels.api as sm

# %%
df = pd.read_csv('advertising.csv')

# %%
x1=df_1[['Tv','Radio','Newspaper']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-af0e718af0cd> in <module>
# ----> 1 x1=df_1[['Tv','Radio','Newspaper']]
#
# NameError: name 'df_1' is not defined

# %%
y1=df['Sales']

# %%
x1=sm.add_constant(x1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-b79edf0cf91e> in <module>
# ----> 1 x1=sm.add_constant(x1)
#
# NameError: name 'x1' is not defined

# %%
model1=sm.OLs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-1e6d5c688dfe> in <module>
# ----> 1 model1=sm.OLs
#
# AttributeError: module 'statsmodels.api' has no attribute 'OLs'
